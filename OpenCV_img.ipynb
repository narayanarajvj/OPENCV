# %% [markdown]
# <a href="https://colab.research.google.com/github/narayanarajvj/OPENCV/blob/master/OpenCV_img.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2

# %%
img = cv2.imread("vijay.jpg",1)

# %%
print(img)
# Out:
# [[[26 23 15]
#   [27 24 16]
#   [28 25 17]
#   ...
#   [17 20 11]
#   [18 21 12]
#   [17 20 11]]
#
#  [[27 24 16]
#   [27 24 16]
#   [28 25 17]
#   ...
#   [18 21 12]
#   [18 21 12]
#   [18 21 12]]
#
#  [[27 24 16]
#   [27 24 16]
#   [28 25 17]
#   ...
#   [18 21 12]
#   [18 21 12]
#   [18 21 12]]
#
#  ...
#
#  [[ 5  8  6]
#   [ 5  8  6]
#   [ 5  9  4]
#   ...
#   [11  9  1]
#   [10  8  0]
#   [ 9  7  0]]
#
#  [[ 4  7  5]
#   [ 4  7  5]
#   [ 5  9  4]
#   ...
#   [11  9  1]
#   [11  9  1]
#   [10  8  0]]
#
#  [[ 4  7  5]
#   [ 4  7  5]
#   [ 5  9  4]
#   ...
#   [12 10  2]
#   [11  9  1]
#   [10  8  0]]]

# %%
print(type(img))
# Out:
# <class 'numpy.ndarray'>

# %%
print(img.shape)
# Out:
# (1024, 576, 3)

# %%
from google.colab.patches import cv2_imshow
cv2_imshow(img)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# <PIL.Image.Image image mode=RGB size=576x1024 at 0x7F4D5F8A75C0>

# %%
resize = cv2.resize(img,(int(img.shape[1]*2),int(img.shape[0]*2)))
cv2_imshow(resize)
# Out:
# <PIL.Image.Image image mode=RGB size=1152x2048 at 0x7F4D5EFD1C88>

# %%
video = cv2.VideoCapture("VJvideo.mp4")
check, frame = video.read()
print(check)
print(frame)
# Out:
# False
# None
